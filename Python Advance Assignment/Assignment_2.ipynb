# %% [markdown]
# <h1 style='text-align:center'>Python Advance : Assignment - 2</h1>
#
# <h3 style='text-align:center'> Submitted by Prasad Aher </h3>
# <br>

# %% [markdown]
# ### Question 1 : What is the relationship between classes and modules?

# %%
# Answer : 
"""
Classes are always nested inside a module. 
Classes are attributes of a module object.
Classes and modules are both namespaces, but classes correspond to statements (not entire files) and
support the OOP notions of multiple instances, inheritance, and operator overloading (modules do not).
In a sense, a module is like a single instance class, without inheritance, which corresponds to an entire file of code.
"""
# Out:
# '\nClasses are always nested inside a module. \nClasses are attributes of a module object.\nClasses and modules are both namespaces, but classes correspond to statements (not entire files) and\nsupport the OOP notions of multiple instances, inheritance, and operator overloading (modules do not).\nIn a sense, a module is like a single instance class, without inheritance, which corresponds to an entire file of code.\n'

# %% [markdown]
# ### Question 2 : How do you make instances and classes?

# %%
# Answer : 
"""
Instances are created by calling a class as it were a function.
and 
Classes are made by running class statements.
"""
# Out:
# '\nInstances are created by calling a class as it were a function.\nand \nClasses are made by running class statements.\n'

# %% [markdown]
# ### Question 3 : Where and how should be class attributes created?

# %%
# Answer: 
"""

Class attributes should be created by assigning attributes to a class object.They are normally generated by top-level
assignments nested in a class statement—each name assigned in the class statement block becomes an attribute of the 
class object.

Class attributes can also be created, by assigning attributes to the class anywhere a reference to the class object
exists.

"""
# Out:
# '\n\nClass attributes should be created by assigning attributes to a class object.They are normally generated by top-level\nassignments nested in a class statement—each name assigned in the class statement block becomes an attribute of the \nclass object.\n\nClass attributes can also be created, by assigning attributes to the class anywhere a reference to the class object\nexists.\n\n'

# %% [markdown]
# ### Question 4 : Where and how are instance attributes created?

# %%
# Answer :
"""
Instance attributes are created by assigning attributes to an instance object. They are normally created within
a class’s method functions coded inside the class statement, by assigning attributes to the self argument

Normally, all instance attributes are initialized in the __init__ constructor method so that way,
later method calls can assume the attributes already exist.
"""
# Out:
# '\nInstance attributes are created by assigning attributes to an instance object. They are normally created within\na class’s method functions coded inside the class statement, by assigning attributes to the self argument\n\nNormally, all instance attributes are initialized in the __init__ constructor method so that way,\nlater method calls can assume the attributes already exist.\n'

# %% [markdown]
# ### Question 5 : What does the term "self" in a Python class mean?

# %%
# Answer :
"""
'self' is the name commonly given to the first (leftmost) argument in a class’s method function;
Python automatically fills it in with the instance object that is the implied subject of the method call.
This argument need not be called 'self', its position is what is significant.
"""
# Out:
# "\n'self' is the name commonly given to the first (leftmost) argument in a class’s method function;\nPython automatically fills it in with the instance object that is the implied subject of the method call.\nThis argument need not be called 'self', its position is what is significant.\n"

# %% [markdown]
# ### Question 6 : How does a Python class handle operator overloading?

# %%
# Answer :
"""

Operator overloading is coded in a Python class with specially named methods;
they all begin and end with double underscores to make them unique. These are
not built-in or reserved names; Python just runs them automatically when an instance
appears in the corresponding operation. Python itself defines the mappings
from operations to special method names.

"""
# Out:
# '\n\nOperator overloading is coded in a Python class with specially named methods;\nthey all begin and end with double underscores to make them unique. These are\nnot built-in or reserved names; Python just runs them automatically when an instance\nappears in the corresponding operation. Python itself defines the mappings\nfrom operations to special method names.\n\n'

# %% [markdown]
# ### Question 7 : When do you consider allowing operator overloading of your classes?

# %%
# Answer : 
"""
Operator overloading is useful to implement objects that resemble built-in types, and to mimic the built-in
type interface expected by a piece of code. Mimicking built-in type interfaces enables you to pass in class instances
that also have state information.
"""
# Out:
# '\nOperator overloading is useful to implement objects that resemble built-in types, and to mimic the built-in\ntype interface expected by a piece of code. Mimicking built-in type interfaces enables you to pass in class instances\nthat also have state information.\n'

# %% [markdown]
# ### Question 8 : What is the most popular form of operator overloading?

# %%
# Answer : 
"""

The __init__ constructor method is the most commonly used

"""
# Out:
# '\n\nThe __init__ constructor method is the most commonly used\n\n'

# %% [markdown]
# ### Question 9 : What are the two most important concepts to grasp in order to comprehend Python OOP code?

# %%
# Answer :

"""

The special self argument in method functions and the __init__ constructor
method are the two cornerstones of OOP code in Python; if you get these, you
should be able to read the text of most OOP Python code—apart from these, it’s
largely just packages of functions. 

"""
# Out:
# '\n\nThe special self argument in method functions and the __init__ constructor\nmethod are the two cornerstones of OOP code in Python; if you get these, you\nshould be able to read the text of most OOP Python code—apart from these, it’s\nlargely just packages of functions. \n\n'
